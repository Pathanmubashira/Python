# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\PATHAN MUBESHIRA\Downloads\data.csv")
df
# Out:
#      Unnamed: 0     id   chol  stab.glu    hdl  ratio      glyhb    location  \
# 0             2   1002  228.0        92   37.0    6.2   4.640000  Buckingham
# 1             6   1011  195.0        92   41.0    4.8   4.840000  Buckingham
# 2             8   1016  177.0        87   49.0    3.6   4.840000  Buckingham
# 3            10   1024  242.0        82   54.0    4.5   4.770000      Louisa
# 4            15   1036  213.0        83   47.0    4.5   3.410000      Louisa
# ..          ...    ...    ...       ...    ...    ...        ...         ...
# 125         394  41254  169.0       104   58.0    2.9   4.820000      Louisa
# 126         395  41500  179.0        85   50.0    3.6   4.990000      Louisa
# 127         397  41503  301.0        90  118.0    2.6   4.280000      Louisa
# 128         398  41506  296.0       369   46.0    6.4  16.110001      Louisa
# 129         399  41507  284.0        89   54.0    5.3   4.390000      Louisa
#
# ...

# %%
shape = df.shape
print("Shape of the DataFrame:", shape)
# Out:
# Shape of the DataFrame: (130, 20)

# %%
size = df.size
print("Size of the DataFrame:", size)
# Out:
# Size of the DataFrame: 2600

# %%
quantiles = df['chol'].describe(percentiles=[0.25, 0.75])

q1 = quantiles['25%']
q3 = quantiles['75%']

print("25th Quantile (Q1):", q1)
print("75th Quantile (Q3):", q3)
# Out:
# 25th Quantile (Q1): 184.25
# 75th Quantile (Q3): 241.5

# %%
dot_product = np.dot(height, weight)

print("Dot Product of Height and Weight:", dot_product)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 dot_product = np.dot(height, weight)
#       3 print("Dot Product of Height and Weight:", dot_product)
#
# NameError: name 'height' is not defined

# %%
percentile_25 = np.percentile("bp.1d", 25)
percentile_75 = np.percentile("bp.1d", 75)

print("25th Percentile:", percentile_25)
print("75th Percentile:", percentile_75)
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 percentile_25 = np.percentile("bp.1d", 25)
#       2 percentile_75 = np.percentile("bp.1d", 75)
#       4 print("25th Percentile:", percentile_25)
#
# File <__array_function__ internals>:200, in percentile(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\numpy\lib\function_base.py:4205, in percentile(a, q, axis, out, overwrite_input, method, keepdims, interpolation)
#    4203 if not _quantile_is_valid(q):
#    4204     raise ValueError("Percentiles must be in the range [0, 100]")
# -> 4205 return _quantile_unchecked(
#    4206     a, q, axis, out, overwrite_input, method, keepdims)
#
# File ~\anaconda3\Lib\site-packages\numpy\lib\function_base.py:4473, in _quantile_unchecked(a, q, axis, out, overwrite_input, method, keepdims)
#    4465 def _quantile_unchecked(a,
# ...

# %%
filtered_hdl = hdl_data[hdl < 50]

# Calculate the median of the filtered 'hdl' data
median_hdl = np.median(filtered_hdl)

print("Median of 'hdl' where 'hdl' is less than 50:", median_hdl)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 filtered_hdl = hdl_data[hdl < 50]
#       3 # Calculate the median of the filtered 'hdl' data
#       4 median_hdl = np.median(filtered_hdl)
#
# NameError: name 'hdl_data' is not defined

# %%
import numpy as np

# Replace these arrays with your actual data
bp_1s = np.array([120, 122, 125, 130, 135, 140, 145, 150, 155, 160])
bp_2s = np.array([120, 122, 130, 130, 135, 142, 145, 148, 155, 160])

# Create a new array with 1s where the condition is met and 0s otherwise
new_array = np.where(bp_1s == bp_2s, 1, 0)

print("New Array based on the condition:", new_array)
# Out:
# New Array based on the condition: [1 1 0 1 1 0 1 0 1 1]
