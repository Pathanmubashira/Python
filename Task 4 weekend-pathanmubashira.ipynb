# %% [markdown]
# #### 1.Take two different integers and check if one variable is factor of the other, if it is a factor print true, otherwise false.

# %%
a=17
b=10
print(a%b==0)
# Out:
# False

# %% [markdown]
# #### 2.use +,* in different strings variables and integers play with the code.

# %%
a=99     
b=1
print(a+b)

c="coca"
d="cola"
print(c+d)

a1="hehe"
a2=10
print(a1*a2)

b1="Pathan"
b2="Mubashira"
print(b1*b2)
# Out:
# 100
# cocacola
# hehehehehehehehehehehehehehehehehehehehe
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 15
#      13 b1="Pathan"
#      14 b2="Mubashira"
# ---> 15 print(b1*b2)
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %% [markdown]
# #### 3.Take two numbers, print true only when one variable is even and the other is odd.

# %%
a=16
b=3
f=(a%3==0)
h=(b%3==0)
print(f or h)
# Out:
# True

# %% [markdown]
# #### 4.a=241, b=340, apply bitwise and, bitwise or, bitwise xor, and a<<2, a>>4 do all of the using pen and paper.

# %%
a=241
b=340
print(a&b)
print(a|b)
print(a^b)
print(a<<2)
print(a>>4)
# Out:
# 80
# 501
# 421
# 964
# 15

# %% [markdown]
# ![DA.jpg](attachment:DA.jpg)
