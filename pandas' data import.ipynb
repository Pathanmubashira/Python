# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\PATHAN MUBESHIRA\Downloads\ethnic_diversity_data_pandas_accessing_task.csv")
df
# Out:
#               Employee_Name       EmpID                  Position State   Zip  \
# 0                Brown, Mia  1103024456              Accountant I    MA  1450
# 1      LaRotonda, William    1106026572              Accountant I    MA  1460
# 2          Steans, Tyrone    1302053333              Accountant I    MA  2703
# 3           Howard, Estelle  1211050782  Administrative Assistant    MA  2170
# 4               Singh, Nan   1307059817  Administrative Assistant    MA  2330
# ..                      ...         ...                       ...   ...   ...
# 305          Daniele, Ann    1411071312      Sr. Network Engineer    CT  6033
# 306          Lajiri,  Jyoti  1108028108      Sr. Network Engineer    MA  2169
# 307  Semizoglou, Jeremiah     904013591      Sr. Network Engineer    MA  1545
# 308              South, Joe  1308060959      Sr. Network Engineer    CT  6278
# 309         Warfield, Sarah  1301052347      Sr. Network Engineer    MA  2453
#
# ...

# %%
#1 minimun salary

df['Salaries'].min()
# Out:
# 0.0

# %%
#2 single employees

df['MaritalDesc'].value_counts()
# Out:
# MaritalDesc
# Single       137
# Married      123
# Divorced      30
# Separated     12
# Widowed        8
# Name: count, dtype: int64

# %%
singles=df.loc[df['MaritalDesc'] == 'Single']
singles
# Out:
#          Employee_Name       EmpID                      Position State    Zip  \
# 2     Steans, Tyrone    1302053333                  Accountant I    MA   2703
# 4          Singh, Nan   1307059817      Administrative Assistant    MA   2330
# 7    Carter, Michelle   1403065721            Area Sales Manager    VT   5664
# 8    Dietrich, Jenna    1408069481            Area Sales Manager    WA  98052
# 10     Friedman, Gerry  1204032843            Area Sales Manager    NY  10171
# ..                 ...         ...                           ...   ...    ...
# 298   Sweetwater, Alex  1001644719  Software Engineering Manager    MA   2184
# 302   Carr, Claudia  N  1010022337                       Sr. DBA    MA   1886
# 303    Favis, Donald    1412071562          Enterprise Architect    CT   6033
# 304   Roehrich, Bianca  1111030266      Principal Data Architect    MA   2703
# 308         South, Joe  1308060959          Sr. Network Engineer    CT   6278
#
# ...

# %%
print("Single employees =",len(singles))
# Out:
# Single employees = 137

# %%
#3 

df['Salaries'].mean()
# Out:
# 36670.10274193549

# %%
# 4 What are the different position in dataset?

df[['Position']].value_counts()
# Out:
# Position
# Production Technician I         136
# Production Technician II         57
# Area Sales Manager               27
# Production Manager               14
# Software Engineer                 9
# IT Support                        8
# Data Analyst                      7
# Sr. Network Engineer              5
# Database Administrator            5
# Network Engineer                  5
# BI Developer                      4
# Administrative Assistant          3
# Senior BI Developer               3
# Sales Manager                     3
# Accountant I                      3
# Sr. DBA                           2
# Sr. Accountant                    2
# Shared Services Manager           2
# IT Manager - DB                   2
# IT Manager - Infra                1
# Data Analyst                      1
# Software Engineering Manager      1
# BI Director                       1
# CIO                               1
# Data Architect                    1
# Director of Operations            1
# ...

# %%
#5

highest_salary = df['Salaries'].max()
print(highest_salary)
# Out:
# 108304.0

# %%
df.loc[df['Salaries'] == highest_salary,'Employee_Name':'Race']
# Out:
#             Employee_Name      EmpID                 Position State   Zip Sex  \
# 216  Kinsella, Kathleen    710007401  Production Technician I    MA  2170   F
#
#     MaritalDesc CitizenDesc        EmploymentStatus         Department  \
# 216     Married  US Citizen  Voluntarily Terminated  Production
#
#      Salaries  age   Race
# 216  108304.0   27  White

# %%
#6

df['Department'].value_counts()
# Out:
# Department
# Production              208
# IT/IS                    50
# Sales                    31
# Admin Offices            10
# Software Engineering     10
# Executive Office          1
# Name: count, dtype: int64

# %%
df.loc[df['Department'].value_counts().max()] ['Department']
# Out:
# 'Production       '

# %%
#7

len(df[df['Sex'] == 'F']['Sex'])
# Out:
# 177

# %%
#8
 
df[df['CitizenDesc'] != 'US Citizen'] ['EmpID']
# Out:
# 6      1504073368
# 26     1209048771
# 58     1011022863
# 72     1411071506
# 102    1101023839
# 134    1403066194
# 146    1407069061
# 165    1012023295
# 188    1102024274
# 222    1405067501
# 234    1103024843
# 240    1402065340
# 263    1201031274
# 271    1207046956
# 288    1206043417
# 297    1102024057
# Name: EmpID, dtype: int64

# %%
#9 

df[df['Race'] == 'Asian'] ['Salaries'].mean()
# Out:
# 40662.373235294115

# %%
#10

df.loc[df['EmploymentStatus'] != 'Active', ['Employee_Name']]
# Out:
#               Employee_Name
# 3           Howard, Estelle
# 5          Smith, Leigh Ann
# 6          Bunbury, Jessica
# 11          Gill, Whitney
# 13          Guilianno, Mike
# ..                      ...
# 303         Favis, Donald
# 304        Roehrich, Bianca
# 305          Daniele, Ann
# 306          Lajiri,  Jyoti
# 307  Semizoglou, Jeremiah
#
# [128 rows x 1 columns]

# %%
df.loc[df['EmploymentStatus'] != 'Active', ['Employee_Name','EmploymentStatus']]
# Out:
#               Employee_Name        EmploymentStatus
# 3           Howard, Estelle    Terminated for Cause
# 5          Smith, Leigh Ann  Voluntarily Terminated
# 6          Bunbury, Jessica  Voluntarily Terminated
# 11          Gill, Whitney      Terminated for Cause
# 13          Guilianno, Mike  Voluntarily Terminated
# ..                      ...                     ...
# 303         Favis, Donald      Terminated for Cause
# 304        Roehrich, Bianca  Voluntarily Terminated
# 305          Daniele, Ann          Leave of Absence
# 306          Lajiri,  Jyoti        Leave of Absence
# 307  Semizoglou, Jeremiah              Future Start
#
# [128 rows x 2 columns]
