# %% [markdown]
# **1. Print your bio data, store name, age, hobbies, parent's name, address and print your outputs : include both static and dynamic texts while printing.**

# %%
name="Pathan Mubashira"
age=23
hobbies="calligraphy and photography"
father_name="Pathan Musthafa"
mother_name="Pathan Mumtaz"
address="Vanasthalipuram, hyderabad"

print("My name is",name)
print("I am",age,"years old")
print("My hobbies are",hobbies,)
print("My father's name is",father_name)
print("My mother's name is", mother_name)
print("I am from",address)
# Out:
# My name is Pathan Mubashira
# I am 23 years old
# My hobbies are calligraphy and photography
# My father's name is Pathan Musthafa
# My mother's name is Pathan Mumtaz
# I am from Vanasthalipuram, hyderabad

# %% [markdown]
# **2.Try to navigate the interface of jupyter notebook by using your own examples add images, hyperlinks, text highlighting etc in different cells.**

# %% [markdown]
# # My Favorite Song

# %% [markdown]
# ### Perfect - Guitar Chords Vocals Only
#
#
# >"Perfect" by `Ed Sheeran` is a heartfelt and enchanting song that beautifully captures the true essence.

# %% [markdown]
# [Click here to listen](https://www.youtube.com/watch?v=AfPXxkWF49I "click here to listen")

# %% [markdown]
# ![edd.jpg](attachment:edd.jpg)
